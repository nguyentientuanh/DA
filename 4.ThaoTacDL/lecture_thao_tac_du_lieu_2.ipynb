# %%
# Lọc dữ liệu
# Gom nhóm dữ liệu
# Tạo cột mới từ cột sẵn có
  # Tạo cột số
  # Tạo cột chữ
  # Tạo cột điều kiện

# TÁCH CỘT

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/shopeep_koreantop_clothing_shop_data.csv')

# %%
df.head()
# Out:
#              pk_shop date_collected     shopid                  name  \
# 0  20210613254711738     2021-06-13  254711738          hello.may.ph
# 1  20210613314198143     2021-06-13  314198143       love.women.shop
# 2   2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3   2021061321407329     2021-06-13   21407329           patriciacai
# 4   2021061311187885     2021-06-13   11187885  Little Market Manila
#
#   join_month  join_day  join_year  item_count  follower_count response_time  \
# 0      April        27       2020         446           17487      10:13:55
# 1  September        25       2020         263            8574      10:43:05
# 2  September        27       2016         209          660417      08:32:07
# 3      April        30       2017         165           18787      09:10:38
# 4    October        18       2016         467           67371      11:40:59
#
#    response_rate               shop_location  rating_bad  rating_good  \
# ...

# %% [markdown]
# # Tách cột

# %%
# Tách cột chữ
# Tách cột ngày tháng

# %% [markdown]
# ## Tách cột chữ

# %%
# df[['ProductName']]

# %%
# df['tên cột']
# .str
# .split('ký hiệu')

# df['tên cột'].str.split('ký hiệu')

# %%
# df['ProductName'].str.split('-')

# %%
# df['ProductName'] -> df['Product'], df['SaleType']
# df['Product'] = df['ProductName'].str.split('-').str[0]
# df['SaleType'] = df['ProductName'].str.split('-').str[1]

# %%
# df.head()

# %%
df['shop_location']
# Out:
# 0                             NaN
# 1        San Nicolas,Metro Manila
# 2         Pasay City,Metro Manila
# 3            Binondo,Metro Manila
# 4      Caloocan City,Metro Manila
#                   ...
# 741            Legazpi City,Albay
# 742                           NaN
# 743                           NaN
# 744          Binondo,Metro Manila
# 745       Pasay City,Metro Manila
# Name: shop_location, Length: 746, dtype: object

# %%
df['District'] = df['shop_location'].str.split(',').str[0]
df['City'] = df['shop_location'].str.split(',').str[1]

# %%
df[['District', 'City']].head()
# Out:
#         District          City
# 0            NaN           NaN
# 1    San Nicolas  Metro Manila
# 2     Pasay City  Metro Manila
# 3        Binondo  Metro Manila
# 4  Caloocan City  Metro Manila

# %%
# ~ text to column

# %% [markdown]
# ## Tách cột ngày tháng

# %%
df['date_collected']
# Out:
# 0      2021-06-13
# 1      2021-06-13
# 2      2021-06-13
# 3      2021-06-13
# 4      2021-06-13
#           ...
# 741    2021-07-06
# 742    2021-07-06
# 743    2021-07-06
# 744    2021-07-06
# 745    2021-07-06
# Name: date_collected, Length: 746, dtype: object

# %%
df['year'] = df['date_collected'].str.split('-').str[0]
df['month'] = df['date_collected'].str.split('-').str[1]
df['day'] = df['date_collected'].str.split('-').str[2]

# %%
df[['year', 'month', 'day']]
# Out:
#      year month day
# 0    2021    06  13
# 1    2021    06  13
# 2    2021    06  13
# 3    2021    06  13
# 4    2021    06  13
# ..    ...   ...  ..
# 741  2021    07  06
# 742  2021    07  06
# 743  2021    07  06
# 744  2021    07  06
# 745  2021    07  06
#
# [746 rows x 3 columns]

# %%
# Cách 2:
df['year'] = pd.to_datetime(df['date_collected']).dt.year
df['month'] = pd.to_datetime(df['date_collected']).dt.month
df['day'] = pd.to_datetime(df['date_collected']).dt.day

# %%
df[['year', 'month', 'day']]
# Out:
#      year  month  day
# 0    2021      6   13
# 1    2021      6   13
# 2    2021      6   13
# 3    2021      6   13
# 4    2021      6   13
# ..    ...    ...  ...
# 741  2021      7    6
# 742  2021      7    6
# 743  2021      7    6
# 744  2021      7    6
# 745  2021      7    6
#
# [746 rows x 3 columns]

# %%
df.head()
# Out:
#              pk_shop date_collected     shopid                  name  \
# 0  20210613254711738     2021-06-13  254711738          hello.may.ph
# 1  20210613314198143     2021-06-13  314198143       love.women.shop
# 2   2021061310377223     2021-06-13   10377223         R&O RedOrange
# 3   2021061321407329     2021-06-13   21407329           patriciacai
# 4   2021061311187885     2021-06-13   11187885  Little Market Manila
#
#   join_month  join_day  join_year  item_count  follower_count response_time  \
# 0      April        27       2020         446           17487      10:13:55
# 1  September        25       2020         263            8574      10:43:05
# 2  September        27       2016         209          660417      08:32:07
# 3      April        30       2017         165           18787      09:10:38
# 4    October        18       2016         467           67371      11:40:59
#
#    ...  rating_good rating_normal  rating_star  is_shopee_verified  \
# ...

# %%
df.columns
# Out:
# Index(['pk_shop', 'date_collected', 'shopid', 'name', 'join_month', 'join_day',
#        'join_year', 'item_count', 'follower_count', 'response_time',
#        'response_rate', 'shop_location', 'rating_bad', 'rating_good',
#        'rating_normal', 'rating_star', 'is_shopee_verified',
#        'is_official_shop', 'District', 'City', 'year', 'month', 'day'],
#       dtype='object')

# %%
df = df[['pk_shop', 'date_collected', 'year', 'month', 'day', 'shopid', 'name', 'join_month', 'join_day',
       'join_year', 'item_count', 'follower_count', 'response_time',
       'response_rate', 'shop_location', 'rating_bad', 'rating_good',
       'rating_normal', 'rating_star', 'is_shopee_verified',
       'is_official_shop', 'District', 'City']]

# %%
df.head()
# Out:
#              pk_shop date_collected  year  month  day     shopid  \
# 0  20210613254711738     2021-06-13  2021      6   13  254711738
# 1  20210613314198143     2021-06-13  2021      6   13  314198143
# 2   2021061310377223     2021-06-13  2021      6   13   10377223
# 3   2021061321407329     2021-06-13  2021      6   13   21407329
# 4   2021061311187885     2021-06-13  2021      6   13   11187885
#
#                    name join_month  join_day  join_year  ...  response_rate  \
# 0          hello.may.ph      April        27       2020  ...             96
# 1       love.women.shop  September        25       2020  ...             73
# 2         R&O RedOrange  September        27       2016  ...             90
# 3           patriciacai      April        30       2017  ...             94
# 4  Little Market Manila    October        18       2016  ...             89
#
#                 shop_location rating_bad  rating_good rating_normal  \
# ...

# %%
df.to_csv('result.csv')

# %%
# Pandas: thư viện trong Python nhằm mục đích xử lý và phân tích dữ liệu

# Pandas:
  # DataFrame: bảng, 2 chiều
  # Series: cột, 1 chiều

# Thao tác dữ liệu

  # Nhập bảng: pd.read_csv('file.csv')
  # Xuất bảng: df.to_csv('result.csv')

  # Xem bảng
    # Xem qua: df.head(), df.tail(), df.sample(5)
    # Xem kỹ
      # Cấu trúc
        # tên cột: df.columns
        # bao nhiêu hàng bao nhiệt cột: df.shape
        # định dạng dữ liệu của từng cột: df.info()
      # Nội dung: df.describe()
        # Thống kê mô tả:
          # Phân biệt population vs. sample
          # Thống kê mô tả: mô tả sample (mẫu)
          # Mô tả chung/khái quát: Measure of Central Tendency (Đo lường trung tâm)
            # mean
            # median
            # mode
          # Mô tả kỹ hơn: Measure of Dispersion (Đo lường phân tán)
            # range: khoảng cách giữa giá trị lớn nhất và nhỏ nhất
            # quantile: phân vị
              # Q1: 25% tập dữ liệu có giá trị nhỏ hơn hoặc bằng Q1
              # Q2: 50% tập dữ liệu có giá trị nhỏ hơn hoặc bằng Q2
              # Q3: 75% tập dữ liệu có giá trị nhỏ hơn hoặc bằng Q2
            # standard deviation (độ lệch chuẩn), variance (phương sai)
              # các điểm dữ liệu đang cách khỏi trung bình bao xa
            # outlier: rất lớn hoặc rất nhỏ so với phần còn lại

  # Truy cập dữ liệu
    # Truy cập trực tiếp: df.loc[tên hàng, tên cột]
    # Truy cập gián tiếp: df.iloc[thứ tự hàng, thứ tự cột]

  # Lọc dữ liệu
    # Lọc cột: df[['cot1', 'cot2', 'cot3']]
    # Lọc hàng: lọc dựa trên điều kiện: df[điều kiện]
      # &: và -> df[(điều kiện 1) & (điều kiện 2)]
      # |: hoặc -> df[(điều kiện 1) | (điều kiện 2)]

  # Xử lý dữ liệu
    # Xử lý cấu trúc
      # Đổi tên cột: df.rename(columns={'tên cũ':'tên mới'})
      # Đổi định dạng dữ liệu của cột:
        # .astype() -> .astype('str')
        # pd.to_datetime: đổi định dạng cột về ngày tháng
      # Thêm cột:
        # df['cột mới'] = giá trị
        # Thêm cột số: df['cột mới'] = df['cột 1'] + df['cột 2'] (số hết)
        # Thêm cột chữ: df['cột mới'] = df['cột chữ 1'] + ' ' + df['cột chữ 2'] (chữ hết)
        # Thêm dựa trên điều kiện
      # Tách cột:
        # Tách cột chữ: df['cột muốn tách'].str.split.str[0]
        # Tách cột ngày tháng: pd.to_datetime(df['date']).dt.year/month/day
      # Bỏ cột: df.drop(cột, axis=1, inplace=True)
      # Thêm dòng: pd.concat([bảng, bảng chứa dòng mới], axis=0)
      # Bỏ dòng: df.drop(dòng, axis=0, inplace=True)
    # Xử lý nội dung:
      # df['cột'].replace(giá trị cũ, giá trị mới, inplace=True)

  # Tóm tắt dữ liệu
    # .pivot_table(values=, index=, column=, aggfunc=)
    # .groupby: df.groupby('nhóm')['giá trị'].hàm()

  # Nối bảng
    # UNION -> pd.concat([df1, df2, df3], axis=0)
    # JOIN -> pd.merge(df1, df2, on='key', how='left')
