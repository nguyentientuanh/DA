# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyentientuanh/DA/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Phan 1

# %%
# 1.Tạo dataFrame rong
df = pd.DataFrame()

# %%
#hien thi 5 dong dau
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 2.Tao Dataframe tu List
lst = ['Kế toán','Kinh doanh','Tiếp thị']

# %%
df = pd.DataFrame(lst)
df
# Out:
#             0
# 0     Kế toán
# 1  Kinh doanh
# 2    Tiếp thị

# %%
# 3.Tao DataFrame tu Tuple
tuples = [('Kế toán', 2000),( 'Kinh doanh', 2100), ('Tiếp thị', 1900)]
df = pd.DataFrame(tuples, columns=['Nghề','Lương'])
df
# Out:
#          Nghề  Lương
# 0     Kế toán   2000
# 1  Kinh doanh   2100
# 2    Tiếp thị   1900

# %%
# 4.Tạo DataFrame từ Dictionary
dic = {'Nghề':['Kế toán','Kinh doanh','Tiếp thị'],
       'Lương':[2000, 2100, 1900]}
df = pd.DataFrame(dic)
df
# Out:
#          Nghề  Lương
# 0     Kế toán   2000
# 1  Kinh doanh   2100
# 2    Tiếp thị   1900

# %% [markdown]
# Phan 2

# %%
# 1.Tạo Series từ Dictionary
dict = {0 : 'Kế toán', 1 : 'Kinh doanh', 2 : 'Tiếp thị'}
seri = pd.Series(dict)
seri
# Out:
# 0       Kế toán
# 1    Kinh doanh
# 2      Tiếp thị
# dtype: object

# %%
# 2. Tao series tu numpy array
#Tạo Numpy array và gán vào cho Series
import numpy as np

# %%
#Tạo Numpy array
arr = np.array([51,65,48,59,68])

# %%
# Gan gia tri cua arry vao Series
seri = pd.Series(arr)
seri
# Out:
# 0    51
# 1    65
# 2    48
# 3    59
# 4    68
# dtype: int64

# %%
# 3.Tao series tu cac gia tri vo huong
seri = pd.Series(10, index=[0,1,2,3,4,5])
seri
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# dtype: int64

# %% [markdown]
# Phan 3

# %%
df = pd.read_csv("/content/FoodPrice_in_Turkey.csv")

# %%
df.shape
df.columns
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Place           object
# ProductId        int64
# ProductName     object
# UmId             int64
# UmName          object
# Month            int64
# Year             int64
# Price          float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %% [markdown]
# ## FoodPrice

# %%
df=pd.read_csv(filepath_or_buffer = '/FoodPrice_in_Turkey.csv')

# %%
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df.rename(columns={'Place':'Địa điểm','ProductName':'Tên SP'},inplace=True)
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df['new_column'] = 'NaN'
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price new_column
# 0  4.4920        NaN
# 1  4.5786        NaN
# 2  4.7865        NaN
# 3  5.1337        NaN
# 4  5.5099        NaN

# %%
del df['new_column']
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df.drop(1, axis = 0, inplace=True)
df
# Out:
#               Địa điểm  ProductId                   Tên SP  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# 5     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 2        11  2013   4.7865
# ...

# %%
tg = df.iloc[3]
tg
# Out:
# Địa điểm     National Average
# ProductId                  52
# Tên SP          Rice - Retail
# UmId                        5
# UmName                     KG
# Month                       1
# Year                     2014
# Price                  5.5099
# Name: 4, dtype: object

# %%
df.replace(5,10,inplace = True)
df.head()
# Out:
#            Địa điểm  ProductId         Tên SP  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail    10     KG     10  2013
# 2  National Average         52  Rice - Retail    10     KG     11  2013
# 3  National Average         52  Rice - Retail    10     KG     12  2013
# 4  National Average         52  Rice - Retail    10     KG      1  2014
# 5  National Average         52  Rice - Retail    10     KG      2  2014
#
#     Price
# 0  4.4920
# 2  4.7865
# 3  5.1337
# 4  5.5099
# 5  5.8146

# %% [markdown]
# ## GDP LIST

# %%
df=pd.read_csv('/GDPlist.csv',encoding = "ISO-8859-1")
df.head()
# Out:
#         Country      Continent  GDP (millions of US$)
# 0   Afghanistan           Asia                  18181
# 1       Albania         Europe                  12847
# 2       Algeria         Africa                 190709
# 3        Angola         Africa                 100948
# 4     Argentina  South America                 447644

# %%
df.rename(columns={'Country':'Quốc gia','Continent':'Chau Luc','GDP (millions of US$)':'GDP (trieu $)'},inplace=True)
df.head()
# Out:
#        Quốc gia       Chau Luc  GDP (trieu $)
# 0   Afghanistan           Asia          18181
# 1       Albania         Europe          12847
# 2       Algeria         Africa         190709
# 3        Angola         Africa         100948
# 4     Argentina  South America         447644

# %%
df.loc[:,'Quốc gia']
# Out:
# 0       Afghanistan
# 1           Albania
# 2           Algeria
# 3            Angola
# 4         Argentina
#            ...
# 120      Uzbekistan
# 121       Venezuela
# 122         Vietnam
# 123           Yemen
# 124          Zambia
# Name: Quốc gia, Length: 125, dtype: object

# %%
df.insert(3,'Thanh Pho3',df.loc[:,'Quốc gia'])
df.head()
# Out:
#        Quốc gia       Chau Luc  GDP (trieu $)    Thanh Pho3    Thanh Pho2  \
# 0   Afghanistan           Asia          18181   Afghanistan   Afghanistan
# 1       Albania         Europe          12847       Albania       Albania
# 2       Algeria         Africa         190709       Algeria       Algeria
# 3        Angola         Africa         100948        Angola        Angola
# 4     Argentina  South America         447644     Argentina     Argentina
#
#    Thanh Pho
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %%
df.drop('Thanh Pho',axis=1,inplace=True)
df.head()
# Out:
#        Quốc gia       Chau Luc  GDP (trieu $)    Thanh Pho3    Thanh Pho2
# 0   Afghanistan           Asia          18181   Afghanistan   Afghanistan
# 1       Albania         Europe          12847       Albania       Albania
# 2       Algeria         Africa         190709       Algeria       Algeria
# 3        Angola         Africa         100948        Angola        Angola
# 4     Argentina  South America         447644     Argentina     Argentina

# %%
df.drop('Thanh Pho2',axis=1,inplace=True)
df.head()
# Out:
#        Quốc gia       Chau Luc  GDP (trieu $)    Thanh Pho3
# 0   Afghanistan           Asia          18181   Afghanistan
# 1       Albania         Europe          12847       Albania
# 2       Algeria         Africa         190709       Algeria
# 3        Angola         Africa         100948        Angola
# 4     Argentina  South America         447644     Argentina

# %%
df.rename(columns={'Thanh Pho3':'Thanh Pho'},inplace=True)
df.head()
# Out:
#        Quốc gia       Chau Luc  GDP (trieu $)     Thanh Pho
# 0   Afghanistan           Asia          18181   Afghanistan
# 1       Albania         Europe          12847       Albania
# 2       Algeria         Africa         190709       Algeria
# 3        Angola         Africa         100948        Angola
# 4     Argentina  South America         447644     Argentina

# %%
df['Thanh Pho'] = df['Thanh Pho'].replace({'Vietnam':'HaNoi'})
df
# Out:
#          Quốc gia       Chau Luc  GDP (trieu $)     Thanh Pho
# 0     Afghanistan           Asia          18181   Afghanistan
# 1         Albania         Europe          12847       Albania
# 2         Algeria         Africa         190709       Algeria
# 3          Angola         Africa         100948        Angola
# 4       Argentina  South America         447644     Argentina
# ..            ...            ...            ...           ...
# 120    Uzbekistan           Asia          45353    Uzbekistan
# 121     Venezuela  South America         315841     Venezuela
# 122       Vietnam           Asia         122722       Vietnam
# 123         Yemen         Africa          33675         Yemen
# 124        Zambia         Africa          19206        Zambia
#
# [125 rows x 4 columns]
